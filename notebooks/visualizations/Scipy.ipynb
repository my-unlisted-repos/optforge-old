# %%
import optforge as of
from optforge.benchmark.vobench_benchmarks import VOBenchmark
import vobench as vb
import numpy as np

def rosenbrock(x, y):
    a = 1
    b = 100
    return (a - x) ** 2 + b * (y - x ** 2) ** 2

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('nelder-mead')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.optim.RandomRestart(of.integrations.ScipyMinimize('nelder-mead'), 100)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500, 500))

optimizer = of.integrations.ScipyMinimize('cobyqa')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0197
# Job finished in 3.1s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('powell')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('cg').rescaled(100)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.5s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('bfgs')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.5s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('l-bfgs-b')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.6s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('tnc', restart='last')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0005
# Job finished in 0.5s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('cobyla', restart='last')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0449
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('cobyqa', restart='last')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 5.7s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('slsqp', restart='last')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.8s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimize('trust-constr', restart='last')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    #bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 1.0s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyBasinhopping()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.4s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyDE()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.6s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipySHGO()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.4s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyDualAnnealing()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyDIRECT()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    #max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# best value: 0.0000
# Job finished in 0.2s., did 988 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyBrute()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyLeastSquares('trf')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0606
# Job finished in 0.4s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyLeastSquares('dogbox')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0630
# Job finished in 0.5s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyLevenbergMarquardt()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0567
# Job finished in 0.1s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('hybr')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0003
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('lm')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.1732
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('broyden1', )

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.1584
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('broyden2',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.1005
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('anderson',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# d:\miniconda3\envs\pytorch312\Lib\site-packages\scipy\optimize\_nonlin.py:1092: LinAlgWarning: Ill-conditioned matrix (rcond=2.50122e-25): result may not be accurate.
#   gamma = solve(self.a, df_f)
# d:\miniconda3\envs\pytorch312\Lib\site-packages\scipy\optimize\_nonlin.py:1092: LinAlgWarning: Ill-conditioned matrix (rcond=2.52284e-20): result may not be accurate.
#   gamma = solve(self.a, df_f)
# d:\miniconda3\envs\pytorch312\Lib\site-packages\scipy\optimize\_nonlin.py:1092: LinAlgWarning: Ill-conditioned matrix (rcond=7.77249e-26): result may not be accurate.
#   gamma = solve(self.a, df_f)
# d:\miniconda3\envs\pytorch312\Lib\site-packages\scipy\optimize\_nonlin.py:1092: LinAlgWarning: Ill-conditioned matrix (rcond=3.67408e-23): result may not be accurate.
#   gamma = solve(self.a, df_f)
# d:\miniconda3\envs\pytorch312\Lib\site-packages\scipy\optimize\_nonlin.py:1092: LinAlgWarning: Ill-conditioned matrix (rcond=2.77055e-19): result may not be accurate.
# ...

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('linearmixing',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 2.2919
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('diagbroyden',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0662
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('excitingmixing',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 9.5435
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('krylov',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.5333
# Job finished in 0.5s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRoot('df-sane',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 4.0756
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimizeScalar('Brent')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.2847
# Job finished in 0.1s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimizeScalar('Bounded')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.1860
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimizeScalar('Golden')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.4166
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimizeScalar('Brent', mode='weighted')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    # bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.2889
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimizeScalar('Bounded', mode='weighted')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0000
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyMinimizeScalar('Golden', mode='weighted')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0905
# Job finished in 0.2s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRootScalar('newton',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 82.3520
# Job finished in 0.6s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRootScalar('secant',)

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0008
# Job finished in 0.4s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRootScalar('newton', mode='weighted')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0317
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.FunctionDescent2D(rosenbrock, coords = [-1.9, -0.9], xrange = (-3, 3), yrange=(-2, 3))

optimizer = of.integrations.ScipyRootScalar('secant', mode='weighted')

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-3, 3)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0004
# Job finished in 0.4s., did 1000 evaluations.
