# %%
import optforge as of
from mads.mads import orthomads
from optforge.benchmarks.vobench_benchmarks import VOBenchmark
import vobench as vb
import numpy as np

inputs = vb.imread(r"F:\Stuff\Programming\AI\VOBench\VOBench\notebooks\affine\A2.jpeg")[:,:,0]
targets = vb.imread(r"F:\Stuff\Programming\AI\VOBench\VOBench\notebooks\affine\A.jpeg")[:,:,0]

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

orthomads(vob.params, [1,1], [-1,-1], vob.step_noline, dp = 0.1, dm = 0.01, dp_tol=0, nitermax=500, displog=False, savelog=False)

vob.plot()
print(vob.current_step)
# Out:
# 1994

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

optimizer = of.integrations.Orthomads()

study = of.minimize(
    vob.step_noline,
    vob.params,
    optimizer,
    max_evals = 1000,
    bounds = (-1, 1)
)

vob.plot()
# Out:
# evals: 1000/1000 | best value: 0.0197
# Job finished in 5.1s., did 1000 evaluations.
