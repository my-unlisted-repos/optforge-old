# %%
import optforge as of
from optforge.benchmark.vobench_benchmarks import VOBenchmark
import vobench as vb
import cars

inputs = vb.imread(r"F:\Stuff\Programming\AI\VOBench\VOBench\notebooks\affine\A2.jpeg")[:,:,0]
targets = vb.imread(r"F:\Stuff\Programming\AI\VOBench\VOBench\notebooks\affine\A.jpeg")[:,:,0]

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

opt = cars.CARS({"alpha": 1e10, 'f_name': 'f_name', "f_module": "f_module", "budget": 10000}, x0 = vob.params, f = vob)
for i in range(1000): opt.step()

vob.plot()
# Out:
# Initialization done.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

opt = of.integrations.CARSOptimizer(cars.CARS,)
of.minimize(vob, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.9333
# Job finished in 0.4s., did 1000 evaluations.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

opt = of.integrations.CARSOptimizer(cars.CARS,).rescaled(0.01)
of.minimize(vob.step_noline, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.0197
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

opt = of.integrations.CARSOptimizer(cars.CARSCR,)
of.minimize(vob, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.9333
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

opt = of.integrations.CARSOptimizer(cars.CARSCR,).rescaled(0.01)
of.minimize(vob.step_noline, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.6555
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

opt = of.integrations.CARSOptimizer(cars.CARSNQ,)
of.minimize(vob, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.9294
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (500,500),)

opt = of.integrations.CARSOptimizer(cars.CARSNQ,).rescaled(0.01)
of.minimize(vob.step_noline, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.0207
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (600,500),)

opt = of.integrations.CARSOptimizer(cars.Nesterov,)
of.minimize(vob, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.9373
# Job finished in 0.3s., did 1000 evaluations.

# %%
vob = vb.ImageDescent(vb.surfaces.OUTWARD_GAUSS, (600,500),)

opt = of.integrations.CARSOptimizer(cars.Nesterov,).rescaled(0.01)
of.minimize(vob.step_noline, vob.params, opt, max_evals=1000)
vob.plot()
# Out:
# Initialization done.
# evals: 1000/1000 | best value: 0.0240
# Job finished in 0.2s., did 1000 evaluations.
